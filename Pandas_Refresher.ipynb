# %% [markdown]
# <a href="https://colab.research.google.com/github/rajarajeswarir/Hands-on-Machine-Learning/blob/main/Pandas_Refresher.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df = pd.DataFrame([[1,2,3], [4,5,6], [7,8,9]], columns=["A", "B", "C"], index=["x", "y", "z"])

# %%
df.columns
# Out:
# Index(['A', 'B', 'C'], dtype='object')

# %%
df.index
# Out:
# Index(['x', 'y', 'z'], dtype='object')

# %%
df.head(1)
# Out:
#    A  B  C
# x  1  2  3

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 3 entries, x to z
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   A       3 non-null      int64
#  1   B       3 non-null      int64
#  2   C       3 non-null      int64
# dtypes: int64(3)
# memory usage: 204.0+ bytes

# %%
df.describe()
# Out:
#          A    B    C
# count  3.0  3.0  3.0
# mean   4.0  5.0  6.0
# std    3.0  3.0  3.0
# min    1.0  2.0  3.0
# 25%    2.5  3.5  4.5
# 50%    4.0  5.0  6.0
# 75%    5.5  6.5  7.5
# max    7.0  8.0  9.0

# %%
df.shape
# Out:
# (3, 3)

# %%
pd.read_csv("C:/Users/Raji/Downloads/coffee.csv")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipython-input-3603327765.py in <cell line: 0>()
# ----> 1 pd.read_csv("C:/Users/Raji/Downloads/coffee.csv")
#
# /usr/local/lib/python3.12/dist-packages/pandas/io/parsers/readers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#    1024     kwds.update(kwds_defaults)
# ...

# %%
from google.colab import files

uploaded = files.upload()

for fn in uploaded.keys():
  print('User uploaded file "{name}" with length {length} bytes'.format(
      name=fn, length=len(uploaded[fn])))
# Out:
#      <input type="file" id="files-37dbdb04-f4d1-435c-ae52-ea5c02218fad" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-37dbdb04-f4d1-435c-ae52-ea5c02218fad">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
df_coffee = pd.read_csv("coffee.csv")
display(df_coffee.head())
# Out:
#          Day Coffee Type  Units Sold
# 0     Monday    Espresso          25
# 1     Monday       Latte          15
# 2    Tuesday    Espresso          30
# 3    Tuesday       Latte          20
# 4  Wednesday    Espresso          35

# %%
from google.colab import files

uploaded_xlsx = files.upload()

for fn in uploaded_xlsx.keys():
  print('User uploaded file "{name}" with length {length} bytes'.format(
      name=fn, length=len(uploaded_xlsx[fn])))
# Out:
#      <input type="file" id="files-809a0125-c4e5-4c52-a147-acc691e1fd13" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-809a0125-c4e5-4c52-a147-acc691e1fd13">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
df_olympics = pd.read_excel("olympics-data.xlsx")
display(df_olympics.head())

# %%
# df_coffee.loc[#Rows, #Cols]
df_coffee.loc[0:2], ["Day", "Units Sold"]
# Out:
# (       Day Coffee Type  Units Sold
#  0   Monday    Espresso          25
#  1   Monday       Latte          15
#  2  Tuesday    Espresso          30,
#  ['Day', 'Units Sold'])

# %%
# iloc uses only index values
df_coffee.iloc[:, 0:2]
# Out:
#           Day Coffee Type
# 0      Monday    Espresso
# 1      Monday       Latte
# 2     Tuesday    Espresso
# 3     Tuesday       Latte
# 4   Wednesday    Espresso
# 5   Wednesday       Latte
# 6    Thursday    Espresso
# 7    Thursday       Latte
# 8      Friday    Espresso
# 9      Friday       Latte
# 10   Saturday    Espresso
# 11   Saturday       Latte
# 12     Sunday    Espresso
# 13     Sunday       Latte

# %%
# Modifying individual value
#df_coffee.loc[0, "Units Sold"] = 5
df_coffee.loc[0:3, "Units Sold"] = 5
display(df_coffee)
# Out:
#           Day Coffee Type  Units Sold
# 0      Monday    Espresso           5
# 1      Monday       Latte           5
# 2     Tuesday    Espresso           5
# 3     Tuesday       Latte           5
# 4   Wednesday    Espresso          35
# 5   Wednesday       Latte          25
# 6    Thursday    Espresso          40
# 7    Thursday       Latte          30
# 8      Friday    Espresso          45
# 9      Friday       Latte          35
# 10   Saturday    Espresso          45
# 11   Saturday       Latte          35
# 12     Sunday    Espresso          45
# 13     Sunday       Latte          35

# %%
# to access specific value
df_coffee.iat[0, 0]
# Out:
# 'Monday'

# %%
df_coffee.sort_values(["Units Sold", "Coffee Type"], ascending=[0,1])
# Out:
#           Day Coffee Type  Units Sold
# 8      Friday    Espresso          45
# 10   Saturday    Espresso          45
# 12     Sunday    Espresso          45
# 6    Thursday    Espresso          40
# 4   Wednesday    Espresso          35
# 9      Friday       Latte          35
# 11   Saturday       Latte          35
# 13     Sunday       Latte          35
# 7    Thursday       Latte          30
# 5   Wednesday       Latte          25
# 0      Monday    Espresso           5
# 2     Tuesday    Espresso           5
# 1      Monday       Latte           5
# 3     Tuesday       Latte           5

# %%
from google.colab import files

uploaded = files.upload()

for fn in uploaded.keys():
  print('User uploaded file "{name}" with length {length} bytes'.format(
      name=fn, length=len(uploaded[fn])))
# Out:
#      <input type="file" id="files-6408d8a7-1ac0-4c94-819b-620a1c70884f" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-6408d8a7-1ac0-4c94-819b-620a1c70884f">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
df_bios = pd.read_csv("bios.csv")
display(df_bios.head())
# Out:
#    athlete_id                   name   born_date    born_city  \
# 0           1  Jean-François Blanchy  1886-12-12     Bordeaux
# 1           2         Arnaud Boetsch  1969-04-01       Meulan
# 2           3           Jean Borotra  1898-08-13     Biarritz
# 3           4        Jacques Brugnon  1895-05-11  Paris VIIIe
# 4           5           Albert Canet  1878-04-17   Wandsworth
#
#             born_region born_country     NOC  height_cm  weight_kg   died_date
# 0               Gironde          FRA  France        NaN        NaN  1960-10-02
# 1              Yvelines          FRA  France      183.0       76.0         NaN
# 2  Pyrénées-Atlantiques          FRA  France      183.0       76.0  1994-07-17
# 3                 Paris          FRA  France      168.0       64.0  1978-03-20
# 4               England          GBR  France        NaN        NaN  1930-07-25

# %%
df_bios.loc[df_bios["height_cm"] > 215, ['name', 'height_cm']]
# Out:
#                          name  height_cm
# 5089       Viktor Pankrashkin      220.0
# 5583     Paulinho Villas Boas      217.0
# 5673           Gunther Behnke      221.0
# 5716                 Uwe Blab      218.0
# 5781           Tommy Burleson      223.0
# 5796            Andy Campbell      218.0
# 6223              Lars Hansen      216.0
# 6270              Hu Zhangbao      216.0
# 6409         Sergey Kovalenko      216.0
# 6420            Jānis Krūmiņš      218.0
# 6504              Luc Longley      220.0
# 6722         Shaquille O'Neal      216.0
# 6937           David Robinson      216.0
# 6978          Arvydas Sabonis      223.0
# 7074           Paulo da Silva      217.0
# 7188       Vladimir Tkachenko      220.0
# 7281         Stojko Vranković      217.0
# 7376      Eurelijus Žukauskas      218.0
# 52608         Aleksey Kazakov      217.0
# 82100           Frédéric Weis      218.0
# 89070                Yao Ming      226.0
# 89075          Roberto Dueñas      221.0
# ...

# %%
df_bios[(df_bios['height_cm'] > 215) & (df_bios['born_country']=='USA')]
# Out:
#         athlete_id              name   born_date  born_city     born_region  \
# 5781          5804    Tommy Burleson  1952-02-24  Crossnore  North Carolina
# 6722          6755  Shaquille O'Neal  1972-03-06     Newark      New Jersey
# 6937          6972    David Robinson  1965-08-06   Key West         Florida
# 123850      126093    Tyson Chandler  1982-10-02    Hanford      California
#
#        born_country            NOC  height_cm  weight_kg died_date
# 5781            USA  United States      223.0      102.0       NaN
# 6722            USA  United States      216.0      137.0       NaN
# 6937            USA  United States      216.0      107.0       NaN
# 123850          USA  United States      216.0      107.0       NaN

# %%
df_bios[df_bios['born_country'].isin(['USA', 'Canada']) & (df_bios['name'].str.startswith("Keith"))]
# Out:
#         athlete_id                name   born_date             born_city  \
# 50929        51288        Keith Carter  1924-08-30                 Akron
# 51185        51544       Keith Russell  1948-01-15                  Mesa
# 52913        53288      Keith Erickson  1944-04-19         San Francisco
# 62678        63144        Keith Notary  1960-01-22        Merritt Island
# 77550        78141       Keith Brantly  1962-05-23  Scott Air Force Base
# 84097        84766  Keith Christiansen  1944-07-14   International Falls
# 94646        95413         Keith Meyer  1938-06-20                Geneva
# 97499        98286       Keith Tkachuk  1972-03-28               Melrose
# 98068        98860       Keith Wegeman  1929-08-28                Denver
# 99921       100722        Keith Carney  1970-02-03            Providence
# 115973      117348     Keith Sanderson  1975-02-02              Plymouth
#
#           born_region born_country            NOC  height_cm  weight_kg  \
# ...

# %%
df_bios.query("height_cm > 215 and born_country == 'USA'")
# Out:
#         athlete_id              name   born_date  born_city     born_region  \
# 5781          5804    Tommy Burleson  1952-02-24  Crossnore  North Carolina
# 6722          6755  Shaquille O'Neal  1972-03-06     Newark      New Jersey
# 6937          6972    David Robinson  1965-08-06   Key West         Florida
# 123850      126093    Tyson Chandler  1982-10-02    Hanford      California
#
#        born_country            NOC  height_cm  weight_kg died_date
# 5781            USA  United States      223.0      102.0       NaN
# 6722            USA  United States      216.0      137.0       NaN
# 6937            USA  United States      216.0      107.0       NaN
# 123850          USA  United States      216.0      107.0       NaN

# %%
# Adding / Removing Columns
display(df_coffee)
# Out:
#           Day Coffee Type  Units Sold
# 0      Monday    Espresso           5
# 1      Monday       Latte           5
# 2     Tuesday    Espresso           5
# 3     Tuesday       Latte           5
# 4   Wednesday    Espresso          35
# 5   Wednesday       Latte          25
# 6    Thursday    Espresso          40
# 7    Thursday       Latte          30
# 8      Friday    Espresso          45
# 9      Friday       Latte          35
# 10   Saturday    Espresso          45
# 11   Saturday       Latte          35
# 12     Sunday    Espresso          45
# 13     Sunday       Latte          35

# %%
df_coffee['Price'] = 4.99
df_coffee["Total Sales"] = df_coffee["Units Sold"] * df_coffee["Price"]
display(df_coffee)
# Out:
#           Day Coffee Type  Units Sold  Price  Total Sales
# 0      Monday    Espresso           5   4.99        24.95
# 1      Monday       Latte           5   4.99        24.95
# 2     Tuesday    Espresso           5   4.99        24.95
# 3     Tuesday       Latte           5   4.99        24.95
# 4   Wednesday    Espresso          35   4.99       174.65
# 5   Wednesday       Latte          25   4.99       124.75
# 6    Thursday    Espresso          40   4.99       199.60
# 7    Thursday       Latte          30   4.99       149.70
# 8      Friday    Espresso          45   4.99       224.55
# 9      Friday       Latte          35   4.99       174.65
# 10   Saturday    Espresso          45   4.99       224.55
# 11   Saturday       Latte          35   4.99       174.65
# 12     Sunday    Espresso          45   4.99       224.55
# 13     Sunday       Latte          35   4.99       174.65

# %%
import numpy as np

df_coffee['new_price'] = np.where(df_coffee['Coffee Type']=='Espresso', 3.99, 5.99)
display(df_coffee)
# Out:
#           Day Coffee Type  Units Sold  Price  Total Sales  new_price
# 0      Monday    Espresso           5   4.99        24.95       3.99
# 1      Monday       Latte           5   4.99        24.95       5.99
# 2     Tuesday    Espresso           5   4.99        24.95       3.99
# 3     Tuesday       Latte           5   4.99        24.95       5.99
# 4   Wednesday    Espresso          35   4.99       174.65       3.99
# 5   Wednesday       Latte          25   4.99       124.75       5.99
# 6    Thursday    Espresso          40   4.99       199.60       3.99
# 7    Thursday       Latte          30   4.99       149.70       5.99
# 8      Friday    Espresso          45   4.99       224.55       3.99
# 9      Friday       Latte          35   4.99       174.65       5.99
# 10   Saturday    Espresso          45   4.99       224.55       3.99
# 11   Saturday       Latte          35   4.99       174.65       5.99
# 12     Sunday    Espresso          45   4.99       224.55       3.99
# ...

# %%
df_coffee.drop(columns=['Price'], inplace=True)
display(df_coffee)
# Out:
#           Day Coffee Type  Units Sold  Total Sales  new_price
# 0      Monday    Espresso           5        24.95       3.99
# 1      Monday       Latte           5        24.95       5.99
# 2     Tuesday    Espresso           5        24.95       3.99
# 3     Tuesday       Latte           5        24.95       5.99
# 4   Wednesday    Espresso          35       174.65       3.99
# 5   Wednesday       Latte          25       124.75       5.99
# 6    Thursday    Espresso          40       199.60       3.99
# 7    Thursday       Latte          30       149.70       5.99
# 8      Friday    Espresso          45       224.55       3.99
# 9      Friday       Latte          35       174.65       5.99
# 10   Saturday    Espresso          45       224.55       3.99
# 11   Saturday       Latte          35       174.65       5.99
# 12     Sunday    Espresso          45       224.55       3.99
# 13     Sunday       Latte          35       174.65       5.99

# %%
df_bios_new = df_bios.copy()

# %%
df_bios_new.head()
# Out:
#    athlete_id                   name   born_date    born_city  \
# 0           1  Jean-François Blanchy  1886-12-12     Bordeaux
# 1           2         Arnaud Boetsch  1969-04-01       Meulan
# 2           3           Jean Borotra  1898-08-13     Biarritz
# 3           4        Jacques Brugnon  1895-05-11  Paris VIIIe
# 4           5           Albert Canet  1878-04-17   Wandsworth
#
#             born_region born_country     NOC  height_cm  weight_kg   died_date
# 0               Gironde          FRA  France        NaN        NaN  1960-10-02
# 1              Yvelines          FRA  France      183.0       76.0         NaN
# 2  Pyrénées-Atlantiques          FRA  France      183.0       76.0  1994-07-17
# 3                 Paris          FRA  France      168.0       64.0  1978-03-20
# 4               England          GBR  France        NaN        NaN  1930-07-25

# %%
df_bios_new['first_name'] = df_bios_new['name'].str.split().str[0]
df_bios_new.head()
# Out:
#    athlete_id                   name   born_date    born_city  \
# 0           1  Jean-François Blanchy  1886-12-12     Bordeaux
# 1           2         Arnaud Boetsch  1969-04-01       Meulan
# 2           3           Jean Borotra  1898-08-13     Biarritz
# 3           4        Jacques Brugnon  1895-05-11  Paris VIIIe
# 4           5           Albert Canet  1878-04-17   Wandsworth
#
#             born_region born_country     NOC  height_cm  weight_kg  \
# 0               Gironde          FRA  France        NaN        NaN
# 1              Yvelines          FRA  France      183.0       76.0
# 2  Pyrénées-Atlantiques          FRA  France      183.0       76.0
# 3                 Paris          FRA  France      168.0       64.0
# 4               England          GBR  France        NaN        NaN
#
#     died_date     first_name
# 0  1960-10-02  Jean-François
# 1         NaN         Arnaud
# 2  1994-07-17           Jean
# 3  1978-03-20        Jacques
# 4  1930-07-25         Albert

# %%
df_bios_new['height_category'] = df_bios_new['height_cm'].apply(lambda x: 'Short' if x <165 else ('Average' if x < 185 else 'Tall'))
df_bios_new.head()
# Out:
#    athlete_id                   name   born_date    born_city  \
# 0           1  Jean-François Blanchy  1886-12-12     Bordeaux
# 1           2         Arnaud Boetsch  1969-04-01       Meulan
# 2           3           Jean Borotra  1898-08-13     Biarritz
# 3           4        Jacques Brugnon  1895-05-11  Paris VIIIe
# 4           5           Albert Canet  1878-04-17   Wandsworth
#
#             born_region born_country     NOC  height_cm  weight_kg  \
# 0               Gironde          FRA  France        NaN        NaN
# 1              Yvelines          FRA  France      183.0       76.0
# 2  Pyrénées-Atlantiques          FRA  France      183.0       76.0
# 3                 Paris          FRA  France      168.0       64.0
# 4               England          GBR  France        NaN        NaN
#
#     died_date     first_name height_category
# 0  1960-10-02  Jean-François            Tall
# 1         NaN         Arnaud         Average
# 2  1994-07-17           Jean         Average
# ...

# %%
df_pivot = df_coffee.pivot_table(index='Coffee Type', values='Total Sales', aggfunc='sum')
df_pivot
# Out:
#              Total Sales
# Coffee Type
# Espresso          1097.8
# Latte              848.3
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# df_pivot['Total Sales'].plot(kind='hist', bins=20, title='Total Sales')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Values</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# df_pivot['Total Sales'].plot(kind='line', figsize=(8, 4), title='Total Sales')
# plt.gca().spines[['top', 'right']].set_visible(False)
